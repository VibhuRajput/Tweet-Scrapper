# %%
import pandas as pd 
import tweepy 


# function displaying data of each tweet 
def printtweetdata(n, ith_tweet): 
	print() 
	print(f"Tweet {n}:") 
	print(f"Username:{ith_tweet[0]}") 
	print(f"Description:{ith_tweet[1]}") 
	print(f"Location:{ith_tweet[2]}") 
	print(f"Following Count:{ith_tweet[3]}") 
	print(f"Follower Count:{ith_tweet[4]}") 
	print(f"Total Tweets:{ith_tweet[5]}") 
	print(f"Retweet Count:{ith_tweet[6]}") 
	print(f"Tweet Text:{ith_tweet[7]}") 
	print(f"Hashtags Used:{ith_tweet[8]}") 


# function to perform data extraction 
def scrape(words, date_since, numtweet): 
	
	# Creating DataFrame using pandas 
	db = pd.DataFrame(columns=['username', 'description', 'location', 'following', 
							'followers', 'totaltweets', 'retweetcount', 'text', 'hashtags']) 
	
	# We are using .Cursor() to search through twitter for the required tweets. 
	# The number of tweets can be restricted using .items(number of tweets) 
	tweets = tweepy.Cursor(api.search, q=words, lang="en", 
						since=date_since, tweet_mode='extended').items(numtweet) 
	
	# .Cursor() returns an iterable object. Each item in 
	# the iterator has various attributes that you can access to 
	# get information about each tweet 
	list_tweets = [tweet for tweet in tweets] 
	
	# Counter to maintain Tweet Count 
	i = 1
	
	# we will iterate over each tweet in the list for extracting information about each tweet 
	for tweet in list_tweets: 
		username = tweet.user.screen_name 
		description = tweet.user.description 
		location = tweet.user.location 
		following = tweet.user.friends_count 
		followers = tweet.user.followers_count 
		totaltweets = tweet.user.statuses_count 
		retweetcount = tweet.retweet_count 
		hashtags = tweet.entities['hashtags'] 
		
		# Retweets can be distinguished by a retweeted_status attribute, 
		# in case it is an invalid reference, except block will be executed 
		try: 
			text = tweet.retweeted_status.full_text 
		except AttributeError: 
			text = tweet.full_text 
		hashtext = list() 
		for j in range(0, len(hashtags)): 
			hashtext.append(hashtags[j]['text']) 
		
		# Here we are appending all the extracted information in the DataFrame 
		ith_tweet = [username, description, location, following, 
					followers, totaltweets, retweetcount, text, hashtext] 
		db.loc[len(db)] = ith_tweet 
		
		# Function call to print tweet data on screen 
		printtweetdata(i, ith_tweet) 
		i = i+1
	filename = 'scraped_tweets.csv'
	
	# we will save our database as a CSV file. 
	db.to_csv(filename) 


if __name__ == '__main__': 
	
	# Enter your own credentials obtained 
	# from your developer account 
	
	auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
	auth.set_access_token(access_key, access_secret) 
	api = tweepy.API(auth) 
	
	# Enter Hashtag and initial date 
	print("Enter Twitter HashTag to search for") 
	words = input() 
	print("Enter Date since The Tweets are required in yyyy-mm--dd") 
	date_since = input() 
	
	# number of tweets you want to extract at one go
	numtweet = 100
	scrape(words, date_since, numtweet) 
	print('Done Scraping!')
# Out:
# Enter Twitter HashTag to search for
# Batman
# Enter Date since The Tweets are required in yyyy-mm--dd
# 2021-01-01
#
# Tweet 1:
# Username:Alwaysflatout
# Description:Loving special folk in my life H,H,C&M 2much anger confusion&division in society lets reconnect Nod smile say hello 2 your neighbour&those we'd normally pass by
# Location:Completely smitten with❤WOW❤
# Following Count:1506
# Follower Count:338
# Total Tweets:9490
# Retweet Count:78
# Tweet Text:Had to come see this for myself. This is all down to the amazing LX team @captheatres - thank you guys. Phenomenal.
#
# @AndyGray59 would have LOVED this. 💜🦇
#
# #Batman https://t.co/gysiPsnxbm
# Hashtags Used:[]
#
# Tweet 2:
# Username:AMacin99
# Description:digital artist @macindrawings on IG
# Location:
# Following Count:332
# Follower Count:52
# Total Tweets:4933
# Retweet Count:57
# Tweet Text:Batman v Superman - Verified Edition https://t.co/S5UkRkwILV
# Hashtags Used:[]
#
# Tweet 3:
# Username:_ldxo
# Description:
# Location:
# Following Count:339
# Follower Count:560
# Total Tweets:30666
# Retweet Count:1
# Tweet Text:thank God i don’t have class tmrw.. i should not be up rn but here i am in the gc arguing that there’s no realistic universe in which Batman can beat Superman or 90% of the avengers
# Hashtags Used:[]
#
# Tweet 4:
# Username:ADun_Batman
# Description:I'm Hispanic
# Location:
# Following Count:129
# Follower Count:138
# Total Tweets:20539
# Retweet Count:19233
# Tweet Text:NO. REPUBLICANS. VOTED. TO. HELP. THE. PEOPLE. https://t.co/GfImdaWIaf
# Hashtags Used:[]
#
# Tweet 5:
# Username:movieweb
# Description:Breaking movie news since the days of dial-up. Est. 1995. 🎥🎬🍿 The latest in 📺: @TVweb
# Location:Hollywood, CA
# Following Count:649
# Follower Count:61566
# Total Tweets:87097
# Retweet Count:0
# Tweet Text:Zack Snyder's 'Justice League' Is Officially Rated-R for Violence and Batman F-Bombs  https://t.co/RBGz3fiaCe
# Hashtags Used:[]
#
# Tweet 6:
# Username:ADun_Batman
# Description:I'm Hispanic
# Location:
# Following Count:129
# Follower Count:138
# Total Tweets:20539
# Retweet Count:2303
# Tweet Text:In 2017 51 Republicans voted in tax relief for the wealthy.
#
# In 2021 0 Republicans voted in Covid relief for the country.
#
# That’s your whole political ad in the 2022 election cycle. https://t.co/bkES72ujJX
# Hashtags Used:[]
#
# Tweet 7:
# Username:JRivers1984
# Description:Just a dude with an interest in the nerd/geek/anime culture. Blogs, writing.  Where are the snows of yesteryear?
# Location:
# Following Count:1172
# Follower Count:183
# Total Tweets:48926
# Retweet Count:4
# Tweet Text:Wonder Woman beats the ENTIRE Justice League (yes, even Batman)! https://t.co/mzXnXlWyu8 #comicpop #wonderwoman #dccomics
# Hashtags Used:['comicpop', 'wonderwoman', 'dccomics']
#
# Tweet 8:
# Username:fuzzypaw_edooks
# Description:Beep boop I am a tiny vanilla-filled robot
# Location:In a sock drawer in Seattle
# Following Count:98
# Follower Count:125
# Total Tweets:50831
# Retweet Count:0
# Tweet Text:No one knows about The Goddamn Batman, but which properties do you think could benefit greatly from a remake?
# Hashtags Used:[]
#
# Tweet 9:
# Username:batman_riquez
# Description:-God -Family -Love -Happiness
# 1ove
#
#         N E B U L A 🛸👽💔☄
# Location:Albuquerque, NM
# Following Count:537
# Follower Count:474
# Total Tweets:12629
# Retweet Count:15255
# Tweet Text:After Hours Tour 2022 https://t.co/zDEuNfkmPC
# Hashtags Used:[]
#
# Tweet 10:
# Username:theanthonydavis
# Description:British broadcaster, writer, voiceover 🎙Veteran @LBC Late Show radio host 📻 @BBC announcer & commentator 🎧 Podcaster & creator of @fiveminnews
# Location:Los Angeles, CA
# Following Count:2238
# Follower Count:13841
# Total Tweets:18438
# Retweet Count:0
# Tweet Text:Very reassuring to know that the UK Health Secretary is getting the best advice from Netflix. Maybe he could summon Batman to sort out this mess? After all, his relatives started the pandemic. #batsignal 🦇 https://t.co/DzFG67sNQ0
# Hashtags Used:['batsignal']
#
# Tweet 11:
# Username:infrarae
# Description:♊︎☉ ♏︎☽ . 26 . graphic designer . icon by @caastlesart . this account is monitored by my parents
# Location:Goldenrod City
# Following Count:2278
# Follower Count:378
# Total Tweets:35391
# Retweet Count:0
# Tweet Text:@TheBat_Family I want to scream every time someone says batman can kill/ shoot people. That already exists and his name is Jason Todd.
# Hashtags Used:[]
#
# Tweet 12:
# Username:UltimateGolde13
# Description:I love to write, I love to draw, and if it wasn't clear enough, I love Golden Peter from Into The Spiderverse!!!!
# Location:
# Following Count:138
# Follower Count:78
# Total Tweets:21112
# Retweet Count:0
# Tweet Text:@bestofvidgames I ship her with the Injustice 2 Batman
# Hashtags Used:[]
#
# Tweet 13:
# Username:nerdist
# Description:Intelligent. Irreverent. Inclusive. Welcome to Nerdist, we're so glad you're here.
# Location:
# Following Count:4048
# Follower Count:470002
# Total Tweets:144288
# Retweet Count:1
# Tweet Text:The Caped Crusaders never looked better than these #BatmanForever deluxe figures from Hot Toys. https://t.co/9cMMDwczMM
# Hashtags Used:['BatmanForever']
#
# Tweet 14:
# Username:CinemaSimpleton
# Description:I am a film and TV fanatic who gives the stuff we watch either the thumbs up or the boot out the door they deserve.
# Location:Canada
# Following Count:1107
# Follower Count:229
# Total Tweets:5052
# Retweet Count:0
# Tweet Text:George Clooney on playing Batman. He actually thought he had killed the franchise.😬
#
# But he also would show up to the set of E.R. wearing the costume.
#
# I mean, wouldn’t you want to see Batman walking around the hospital?
#
# #Batmanmarathon
# #BatmanandRobin
#
# https://t.co/FChXYsrPDw
# Hashtags Used:['Batmanmarathon', 'BatmanandRobin']
#
# Tweet 15:
# Username:notpatrickgrant
# Description:uva '19/20 he/him
# Location:
# Following Count:391
# Follower Count:158
# Total Tweets:211
# Retweet Count:0
# Tweet Text:@h__mg Picturing a Batman-style utility belt clipped with all your specialized shoes you wear at all times
# Hashtags Used:[]
#
# Tweet 16:
# Username:watcherhotdog
# Description:Comics. DC and Marvel 🙏🙏🙏
# Location:Read Mister Miracle. He/Him
# Following Count:1688
# Follower Count:815
# Total Tweets:35776
# Retweet Count:76
# Tweet Text:batman waking up from unconsciousness after superman and darksied have destroyed everything but somehow joker is still alive. https://t.co/VqyIpluUTN
# Hashtags Used:[]
#
# Tweet 17:
# Username:hijabi_nerd
# Description:she/her l bi but only on the internet don’t tell my mom I 23 | where are the rest of the arab/Muslim DC comics fans
# Location:
# Following Count:169
# Follower Count:114
# Total Tweets:1447
# Retweet Count:1
# Tweet Text:streets saying wonder zionist and batman gonna be fuсking in the batwing
# https://t.co/hcH2lSz66F https://t.co/nZIj9d9y5O
# Hashtags Used:[]
#
# Tweet 18:
# Username:batman_really
# Description:"Swap meat for chrome, live a BD fantasy, whatever, but at the end of it all, it's the code you live by that defines who you are. "
# Location:Night City, CA
# Following Count:198
# Follower Count:243
# Total Tweets:24752
# Retweet Count:0
# Tweet Text:Black panther is mid https://t.co/quntLbkiuP
# Hashtags Used:[]
#
# Tweet 19:
# Username:Seankitskit
# Description:
# Location:
# Following Count:3
# Follower Count:21
# Total Tweets:384704
# Retweet Count:0
# Tweet Text:Roses cats! red! violets are blue Batman Wars Jurassic Rings Alien , Day! Armagedon Saving Black Iron Zone secrets Avengers Of Titanic The Wolf
# Hashtags Used:[]
#
# Tweet 20:
# Username:revrim
# Description:Co-host of the @DCsquadcast and @horrorcomicspod - Singer @house_lalo - Bassist @hydrogenchild.
# Location:Shreveport, La
# Following Count:1234
# Follower Count:1112
# Total Tweets:7972
# Retweet Count:57
# Tweet Text:Batman v Superman - Verified Edition https://t.co/S5UkRkwILV
# Hashtags Used:[]
#
# Tweet 21:
# Username:jxxx_09
# Description:lol
# Location:burger king
# Following Count:69
# Follower Count:9
# Total Tweets:11
# Retweet Count:3
# Tweet Text:He was once none as the guy from twilight he is now none as da mf batman https://t.co/CEljsITUHR
# Hashtags Used:[]
#
# Tweet 22:
# Username:MistyNeon
# Description:ben | 22 | everything cool you like was invented by marginalized communities | black lives matter | 🇵🇭 | he/they
# Location:
# Following Count:682
# Follower Count:63
# Total Tweets:1779
# Retweet Count:352
# Tweet Text:"They’re not nearly scared enough. But they will be."
#
# #scarecrow new design, hope u like it, friends! ⁦@tomeu_morey⁩ colors🔥
# March 2. #DCInfiniteFrontier
# And #batman #106
# ⁦@thedcnation⁩ ⁦@DCComics⁩ https://t.co/ARFTL5IyCI
# Hashtags Used:['scarecrow']
#
# Tweet 23:
# Username:CandiottiCE
# Description:Papá de Oriana, @BarcelonaSC @juventusfc @BocaJrsOficial. De la tierra verde. Pro Vida💙. Marvelita.
# Location:Esmeraldas. Ecuador.
# Following Count:1396
# Follower Count:680
# Total Tweets:36359
# Retweet Count:208
# Tweet Text:Joker in #ZackSnydersJusticeLeague... Joker in Batman #1... https://t.co/dK6UgyCSE9
# Hashtags Used:['ZackSnydersJusticeLeague']
#
# Tweet 24:
# Username:EdwardArnett3
# Description:
# Location:
# Following Count:69
# Follower Count:11
# Total Tweets:707
# Retweet Count:0
# Tweet Text:@DavidAContrer12 @IGN Oh really Shazam, aquaman, Wonder Woman, Superman, even Batman had the best fight scene ever
# Hashtags Used:[]
#
# Tweet 25:
# Username:bazooka_boxing
# Description:Bazooka Boxing Academy |Everything boxing https://t.co/hZ9txJMmSI Boxing camp battle rap
# Location:Pennsylvania, USA
# Following Count:1910
# Follower Count:410
# Total Tweets:13138
# Retweet Count:0
# Tweet Text:@ARTMANBOXING @wbcmoro @MikeCoppinger All their heroes are fake superman batman rocky santa 🎅 Jesus etc... they hate seeing real ppl rule every sport!!! Even golf n car racing where blacks are barely allowed in! Ali Hank Aaron Jackie Robinson we thank you for paving the way! I hope wilder 1 day gets justice!!!
# Hashtags Used:[]
#
# Tweet 26:
# Username:thelivingtribu2
# Description:opinions and views are my own. a fellow comic book fan/geek/nerd/gamer/film lover/human being. i welcome new friends and followers and i banish trolls.
# Location:
# Following Count:547
# Follower Count:181
# Total Tweets:57690
# Retweet Count:0
# Tweet Text:@DJGleyber Batman has killed. Many times in the source material.
# Hashtags Used:[]
#
# Tweet 27:
# Username:bae_play1
# Description:Love. Salt. Video Games.
#
# Twitch affiliates with a little too much time and too many cats.
#
# https://t.co/PTCTNtYrDd
# Location:South Carolina, USA
# Following Count:58
# Follower Count:57
# Total Tweets:184
# Retweet Count:0
# Tweet Text:@life_roccos I laugh like B rated Batman villain all the time.
# Hashtags Used:[]
#
# Tweet 28:
# Username:SpiderKnightART
# Description:| He/Him | Comic Artist/Writer | 17 | Working to open comms |  Fat-admirer | Mormon | Asexual | Autistic | NERD | Marvel/DC | #ThiccIsTheWay
# Location:My imagination
# Following Count:834
# Follower Count:1150
# Total Tweets:36551
# Retweet Count:76
# Tweet Text:batman waking up from unconsciousness after superman and darksied have destroyed everything but somehow joker is still alive. https://t.co/VqyIpluUTN
# Hashtags Used:[]
#
# Tweet 29:
# Username:tyrababyra
# Description:❤️🇧🇸
# Location:
# Following Count:354
# Follower Count:66
# Total Tweets:1179
# Retweet Count:0
# Tweet Text:“Batman fighting Robin pull up”...GIRL go sit down🤣🤣🤣 https://t.co/R70N7uajd3 https://t.co/Oxm7VXlyli
# Hashtags Used:[]
#
# Tweet 30:
# Username:gregalthoff
# Description:Comedian, Comicbook fan, leprachaun denier.
# Location:Dubuque, IA
# Following Count:580
# Follower Count:147
# Total Tweets:4222
# Retweet Count:0
# Tweet Text:@Newsarama In the words of Batman, “Aw, fuck.”
# Hashtags Used:[]
#
# Tweet 31:
# Username:AndrewT27712366
# Description:HarryPotter fan\StarWars fan\anime\really likes cartoons\also really big marvel and DC fan\loves animaniacs #yakko #wakko #dot
# Location:
# Following Count:85
# Follower Count:5
# Total Tweets:285
# Retweet Count:0
# Tweet Text:@RealKevinConroy do you have any plans for returning as batman in any future animated Batman shows\movies because i know you’re probably not going to be in unless mark is in to play the joker.
# Hashtags Used:[]
# Tweet 32:
# Username:GaloreFinds
# Description:Great Vintage Finds from around the world! Proud Mom of 2 sets of Twins! https://t.co/8yZ7kD8aQT… #Vintage #Collectibles #StaySafe #Wearamask #SmallBiz #Etsy
# Location:
# Following Count:1833
# Follower Count:1054
# Total Tweets:2915
# Retweet Count:1
# Tweet Text:Vintage Pair Of McDonald's Clear Pressed Glass Mugs For  DC Comic's Movie Batman, Batman Fighting And The Other Has The Joker Escaping https://t.co/7Fk2f1iIPR via @Etsy
# Hashtags Used:[]
#
# Tweet 33:
# Username:BandaYeah
# Description:a veces estoy más arreglado que si fuera viernes.
# Location:Depto. de Carnisalchichonería
# Following Count:494
# Follower Count:617
# Total Tweets:10736
# Retweet Count:0
# Tweet Text:Seis juegos favoritos, sin ningún orden en particular:
#
# 1. TLOZ: Twilight Princess
# 2. Uncharted 2
# 3. Bioshock Infinite
# 4. Okami Den
# 5. Professor Layton and the unwound future
# 6. Batman: Arkham Asylum
#
# @robinLotjonen @astrocitoMX @eXL1nk
# Hashtags Used:[]
#
# Tweet 34:
# Username:ri_1726
# Description:God-fearing, family oriented, sports fanatic, music junkie; Trinbagonian.
# #TriniTwitter |🇹🇹
# #ForzaInter 🖤💙
# #LakeShow
# Location:Trinidad & Tobago
# Following Count:584
# Follower Count:369
# Total Tweets:55654
# Retweet Count:0
# Tweet Text:@TheSaraiAshari Batman fighting Robin pull up... 💀
#
# @JustGeneil, I does remix songs on wildness, but I think she dead ass serious.
#
# 😅😅😅
# Hashtags Used:[]
#
# Tweet 35:
# Username:cipherEquality
# Description:Celebrating the U N I versal SELF 🌌 Laws of Attraction 1️⃣ One Human Family 🌍🧞‍♀️ #iandiAmOneLove
# Location:Now
# Following Count:664
# Follower Count:5990
# Total Tweets:807863
# Retweet Count:13
# Tweet Text:Batman Soul of the Dragon
# pretty decent 70s denny o'niel inspired batman flick with a bit of 70s martial arts inspiration and some 60s/70s bond too
# its just a loveletter to that entire decade really, and its pretty solid https://t.co/VIbVuVpM53
# Hashtags Used:[]
#
# Tweet 36:
# Username:HolyIdiomBatman
# Description:Bot that tweets random permutations of, Holy ____ Batman!. By @amarriner
# Location:The Batcave, Gotham City
# Following Count:0
# Follower Count:44
# Total Tweets:25275
# Retweet Count:0
# Tweet Text:Holy put your dibs on, Batman!
# Hashtags Used:[]
#
# Tweet 37:
# Username:revan_unicorn
# Description:Birdman/ invincible/ sandman/ mecha/ anime(I love banagher links) (they/them  27 y) I guess I am NSFW, Meowriza Gang
# Location:
# Following Count:2249
# Follower Count:165
# Total Tweets:13159
# Retweet Count:4
# Tweet Text:Wonder Woman beats the ENTIRE Justice League (yes, even Batman)! https://t.co/mzXnXlWyu8 #comicpop #wonderwoman #dccomics
# Hashtags Used:['comicpop', 'wonderwoman', 'dccomics']
#
# Tweet 38:
# Username:stamkos33
# Description:Associate Producer on Zack Snyder's Justice League
#
# #releasetheayercut  #releasethesnyderverse.
# #AlitaArmy #Alitasequel
# #duelofthefates
# Location:
# Following Count:145
# Follower Count:104
# Total Tweets:3094
# Retweet Count:4
# Tweet Text:Haters: JUSTICE LEAGUE SHOULDNT BE R.COMIC BOOK MOVIES ARE FOR KIDS.
#
# Me: Why weren't you this angry over Logan or Deadpool 1/2
#
# Haters: (Argument changes) Well...Those guys had mature comics.
#
# Me: So has Batman/The Flash/Superman etc
#
# Haters: *stuttering* uhh Fuck Zack Snyder https://t.co/CQC2oET9p6
# Hashtags Used:[]
#
# Tweet 39:
# Username:DavidLloydWill8
# Description:Poet, stained glass artist. Anti politics, politicians and ideology. Believer in individualism, inventiveness, creativity and freedom.
# Location:Chipping Norton, England
# Following Count:115
# Follower Count:497
# Total Tweets:251
# Retweet Count:0
# Tweet Text:@elpis_of_batman @JaniceW78256134 We used to have a rebellious streak running through our national identity. I used to hear the phrase - Rules are there to be broken. Now many seem overly keen to obey the rules. Like, masks are not required outside but they wear them to go the extra mile for the government.
# Hashtags Used:[]
#
# Tweet 40:
# Username:Batman_Beware
# Description:Yes this is that Batman guy who people accidentally follow, don't be one of those people... Beware the Batman!
# Location:Gotham City
# Following Count:780
# Follower Count:3017
# Total Tweets:116291
# Retweet Count:25
# Tweet Text:🚨🚨🚨
#
# You can now see all of your ratings on the website! Complete with range filtering on ratings! https://t.co/HhfuqEu1IU
# Hashtags Used:[]
#
# Tweet 41:
# Username:MidwestMonster_
# Description:Re-writing unwritten writings. He/him. Living in Wild America.
# Location:Union Blue Ohio!
# Following Count:686
# Follower Count:509
# Total Tweets:23759
# Retweet Count:0
# Tweet Text:Holy moley Batman!
# I need to read before hitting enter because that last one is almost unintelligible.
# #NeedAnEditor
# Hashtags Used:['NeedAnEditor']
#
# Tweet 42:
# Username:readwithout
# Description:| he/him | 17 | Marvel/DC/Star Wars fan | BLM | 🏳️‍🌈 |  pansexual | don't forget the hyphen between "Spider" and "Man" |
# Location:Poland
# Following Count:168
# Follower Count:31
# Total Tweets:604
# Retweet Count:0
# Tweet Text:@khan250101 And BvS is a masterpiece, best Batman movie ever made!
# Hashtags Used:[]
#
# Tweet 43:
# Username:frankitocool
# Description:
# Location:Corrientes, Argentina
# Following Count:2577
# Follower Count:129
# Total Tweets:6737
# Retweet Count:0
# Tweet Text:Batman vs Captain america
#
# Mike Zeck
#
# #Batman #dccomics #comics #capitanamerica @Marvel @DCComics @CaptainAmerica https://t.co/XoWVT34DyZ
# Hashtags Used:['Batman', 'dccomics', 'comics', 'capitanamerica']
#
# Tweet 44:
# Username:DeadPizza
# Description:In the 0.5% of listeners of The Wonder Years this year. That should say a lot about me.
# Location:Came Out Swinging out of CO
# Following Count:2358
# Follower Count:849
# Total Tweets:55520
# Retweet Count:4
# Tweet Text:Wonder Woman beats the ENTIRE Justice League (yes, even Batman)! https://t.co/mzXnXlWyu8 #comicpop #wonderwoman #dccomics
# Hashtags Used:['comicpop', 'wonderwoman', 'dccomics']
#
# Tweet 45:
# Username:shrubbinatorbot
# Description:
# Location:
# Following Count:0
# Follower Count:32
# Total Tweets:280400
# Retweet Count:0
# Tweet Text:NEW INVENTION! 'The Nice Batman' is an ipad pig for $1,000
# Hashtags Used:[]
#
# Tweet 46:
# Username:batman_riquez
# Description:-God -Family -Love -Happiness
# 1ove
#
#         N E B U L A 🛸👽💔☄
# Location:Albuquerque, NM
# Following Count:537
# Follower Count:474
# Total Tweets:12629
# Retweet Count:1
# Tweet Text:It could’ve been you
# Hashtags Used:[]
#
# Tweet 47:
# Username:ZSJL_
# Description:#ZackSnydersJusticeLeague🙅🏻‍♀️⚡️🦾🦇🔱#RestoreTheSnyderVerse 🐇 🕳
# Location:
# Following Count:89
# Follower Count:56
# Total Tweets:3403
# Retweet Count:4
# Tweet Text:Haters: JUSTICE LEAGUE SHOULDNT BE R.COMIC BOOK MOVIES ARE FOR KIDS.
#
# Me: Why weren't you this angry over Logan or Deadpool 1/2
#
# Haters: (Argument changes) Well...Those guys had mature comics.
#
# Me: So has Batman/The Flash/Superman etc
#
# Haters: *stuttering* uhh Fuck Zack Snyder https://t.co/CQC2oET9p6
# Hashtags Used:[]
#
# Tweet 48:
# Username:midnightooker
# Description:ben aslında yoğum
# Location:sütçüoğlu apartmanı
# Following Count:543
# Follower Count:904
# Total Tweets:9971
# Retweet Count:1
# Tweet Text:me attending                  rewatching
# my online             batman v superman
# classes                    for the 100th time https://t.co/C5WARZiUch
# Hashtags Used:[]
#
# Tweet 49:
# Username:tinnypeete613
# Description:Psychist
# Location:
# Following Count:145
# Follower Count:32
# Total Tweets:4124
# Retweet Count:2
# Tweet Text:Do yourself a favor and pick up the latest Batman: Black &amp; White series. Amazing. More of this from the big-2.
# Art by David Aja… https://t.co/YcHxZHxs7D
# Hashtags Used:[]
#
# Tweet 50:
# Username:origSKETCH
# Description:
# Location:
# Following Count:301
# Follower Count:22
# Total Tweets:69
# Retweet Count:124
# Tweet Text:I gotta say, because it’s the truth, Dan Mora’s superhero work is a modern synthesis of José Luis García-López and Jim Lee. if DC relaunched BATMAN to a #1 with Mora on the book, the planet would tremble under the weight of readers rushing to snag a copy, I promise you. https://t.co/CfSk1UywMQ
# Hashtags Used:[]
#
# Tweet 51:
# Username:batman_riquez
# Description:-God -Family -Love -Happiness
# 1ove
#
#         N E B U L A 🛸👽💔☄
# Location:Albuquerque, NM
# Following Count:537
# Follower Count:474
# Total Tweets:12629
# Retweet Count:338
# Tweet Text:Another Day, Another Opportunity💯
# Hashtags Used:[]
#
# Tweet 52:
# Username:immortalpluto99
# Description:rizzoooooo rat B) | 17 | bi
# Location:she/her
# Following Count:167
# Follower Count:22
# Total Tweets:722
# Retweet Count:0
# Tweet Text:@Z1GZAG_ like batman? or more like thanos? or more like mr freeze?
# Hashtags Used:[]
#
# Tweet 53:
# Username:MrOilRich
# Description:William J Clark  is chief executive officer assistant *2 serving directly underneath Mr.Darren W Woods @ #ExxonMobil
# Location:Beverly Hills, CA
# Following Count:117
# Follower Count:6
# Total Tweets:77
# Retweet Count:0
# Tweet Text:Where the f*** are my keys before I knock your dick in the dirt #Batman @trvisXX 👿 https://t.co/jXXW5a9KB3
# Hashtags Used:['Batman']
#
# Tweet 54:
# Username:_luisFilipePT
# Description:Software Engineer aka Enthusiastic Developer… Problem Solver by nature.
# Location:Leiria, Portugal
# Following Count:144
# Follower Count:43
# Total Tweets:136
# Retweet Count:0
# Tweet Text:@ampsantos0 @secretlabchairs https://t.co/EJkZZnxyTR
#
# Mine is the OMEGA 2020 Dark Knight Edition (because I am a "small" guy I didn't choose the Titan)
#
# So far I am pretty satisfied, looks like an apple product :) all the unboxing and assembling experience!
# Hashtags Used:[]
#
# Tweet 55:
# Username:Spidarro
# Description:Avid doodler and graphic designer. Fan of comic books, music, games and all things visual or creative.  Scryer of spiders
# Location:Ireland
# Following Count:3111
# Follower Count:192
# Total Tweets:18880
# Retweet Count:352
# Tweet Text:"They’re not nearly scared enough. But they will be."
#
# #scarecrow new design, hope u like it, friends! ⁦@tomeu_morey⁩ colors🔥
# March 2. #DCInfiniteFrontier
# And #batman #106
# ⁦@thedcnation⁩ ⁦@DCComics⁩ https://t.co/ARFTL5IyCI
# Hashtags Used:['scarecrow']
#
# Tweet 56:
# Username:BraydenSylva
# Description:Native Hawaiian-Samoan. Bisexual. He/Him/She/Her. 21. Got ADHD & DID. Actor/Screenwriter/Director.
# Location:Las Vegas, NV
# Following Count:5000
# Follower Count:1653
# Total Tweets:170165
# Retweet Count:4
# Tweet Text:Wonder Woman beats the ENTIRE Justice League (yes, even Batman)! https://t.co/mzXnXlWyu8 #comicpop #wonderwoman #dccomics
# Hashtags Used:['comicpop', 'wonderwoman', 'dccomics']
#
# Tweet 57:
# Username:JOK3YY
# Description:| Professional Laugh-Maker | | Marvel/Star Wars/ DC Nerd | | Amateur YouTuber | | Voice Impression Artist/ Voice Actor | | King of Lowering Expectations |
# Location:
# Following Count:422
# Follower Count:277
# Total Tweets:41361
# Retweet Count:2090
# Tweet Text:Tom Holland says that while filming 'Spider-Man: Homecoming' (2017), Michael Keaton would whisper 'I'm Batman' during fight scenes https://t.co/7MQDwfBpTq
# Hashtags Used:[]
#
# Tweet 58:
# Username:EugeneAuthor97
# Description:I'm an Autistic writer who's a published Author on @BooksieWriting. 😁
# Location:
# Following Count:5000
# Follower Count:1889
# Total Tweets:173355
# Retweet Count:7
# Tweet Text:.@JorgeJimenezArt shared a new design for the evil Dr. Jonathan Crane/Scarecrow that will debut in his, @JamesTheFourth and @tomeu_morey's Batman run in March.
#
# https://t.co/I7jyaisZvb https://t.co/Gatrum2ztb
# Hashtags Used:[]
#
# Tweet 59:
# Username:dannysfuntime
# Description:11 years young turning 12 years young :) he/him
# Location:Chicagoland or something
# Following Count:494
# Follower Count:483
# Total Tweets:3535
# Retweet Count:0
# Tweet Text:Oh no... batman was at the capitol https://t.co/ssXwdoNzK6
# Hashtags Used:[]
#
# Tweet 60:
# Username:Sonchichi5
# Description:my name is son chichi, Wife of Goku, mother of Gohan and Goten, grandmother of pan and daughter of the mighty Ox King. You mess with my family, watch out.
# Location:Fire Mountain, Mount Paozu
# Following Count:749
# Follower Count:595
# Total Tweets:19580
# Retweet Count:1
# Tweet Text:i made it to 800 followers on here. Holy popularity Batman. https://t.co/rMQZA3th4u
# Hashtags Used:[]
# Tweet 61:
# Username:batman_really
# Description:"Swap meat for chrome, live a BD fantasy, whatever, but at the end of it all, it's the code you live by that defines who you are. "
# Location:Night City, CA
# Following Count:198
# Follower Count:243
# Total Tweets:24752
# Retweet Count:0
# Tweet Text:1 like = 1 movie hot take https://t.co/JV60CrJxp5
# Hashtags Used:[]
#
# Tweet 62:
# Username:iCreativeArtist
# Description:We are in an age of real-life superheroes; and several of whom have lived a life SO meaningful...they (and their deeds) are legendary.
# Location:Roanoke Virginia
# Following Count:1022
# Follower Count:1243
# Total Tweets:22960
# Retweet Count:0
# Tweet Text:@fmniaz1Tweets Imagine Stark's struggles of wanting to come clean to Iron Man's teammates so as to be accepted as a man of integrity, but for fear of putting Pepper in jeopardy...he has to keep silent; much like how Batman has to do.
#
# It may've been an interesting performance to see play out.
# Hashtags Used:[]
#
# Tweet 63:
# Username:SalSaysWhat
# Description:Making funny videos about comic books for a living aka #comicpop. For business inquiries, email me: sal@comicpop.net.
# Location:
# Following Count:79
# Follower Count:13515
# Total Tweets:30833
# Retweet Count:4
# Tweet Text:Wonder Woman beats the ENTIRE Justice League (yes, even Batman)! https://t.co/mzXnXlWyu8 #comicpop #wonderwoman #dccomics
# Hashtags Used:['comicpop', 'wonderwoman', 'dccomics']
#
# Tweet 64:
# Username:ppa_2d
# Description:ENG/ID | R18 ok | BL | FUB free | I do fanart | ⚠️ Repost without credit is prohibited!
# Location:icon by fejufej
# Following Count:269
# Follower Count:2003
# Total Tweets:19623
# Retweet Count:0
# Tweet Text:Manifesting batman edgy boy
# Hashtags Used:[]
#
# Tweet 65:
# Username:BruceWayne_214
# Description:Comic Book fan. Associate Producer of Zack Snyder's Justice League. Hyped for Army of the Dead. #FreePalestine
# Location:Snyderverse
# Following Count:403
# Follower Count:624
# Total Tweets:18056
# Retweet Count:4
# Tweet Text:Haters: JUSTICE LEAGUE SHOULDNT BE R.COMIC BOOK MOVIES ARE FOR KIDS.
#
# Me: Why weren't you this angry over Logan or Deadpool 1/2
#
# Haters: (Argument changes) Well...Those guys had mature comics.
#
# Me: So has Batman/The Flash/Superman etc
#
# Haters: *stuttering* uhh Fuck Zack Snyder https://t.co/CQC2oET9p6
# Hashtags Used:[]
#
# Tweet 66:
# Username:MrBeardsly
# Description:A bearded dragon. Author of Wild Worlds Trying to make your feed just a little bit brighter. #LitRPG #fantasy #scifi
# wildworldswriter@gmail.com
# Location:Someplace
# Following Count:3624
# Follower Count:2234
# Total Tweets:10483
# Retweet Count:0
# Tweet Text:@TheBat_Family I don't think that's ever been explored in any film. It would be new and refreshing. Heck, can Batman in general get more love from DC? It seems like they never make an animated movie starring or mainly about him.
# Hashtags Used:[]
#
# Tweet 67:
# Username:Zorro_fast
# Description:i don't follow back and fan of Star Wars,Dc,Marvel,anime,video game and cartoon. Movie and Tv show not too much
# Location:
# Following Count:425
# Follower Count:74
# Total Tweets:4601
# Retweet Count:10
# Tweet Text:In the V15.30 update, a new Batman icon was added into the files.
#
# We could POTENTIALLY see another Batman X Fortnite crossover in the near future!
#
# This is just pure speculation and does not confirm anything. https://t.co/Tts8kLG6cJ
# Hashtags Used:[]
#
# Tweet 68:
# Username:EndermenLord
# Description:☆ Instragram: tiranossauro_30
#
# ♡ Segue eu aí pó =) ♡
# Location:Trancado no Quarto =)
# Following Count:67
# Follower Count:40
# Total Tweets:767
# Retweet Count:10
# Tweet Text:In the V15.30 update, a new Batman icon was added into the files.
#
# We could POTENTIALLY see another Batman X Fortnite crossover in the near future!
#
# This is just pure speculation and does not confirm anything. https://t.co/Tts8kLG6cJ
# Hashtags Used:[]
#
# Tweet 69:
# Username:dollface_carmen
# Description:Twenty fine ✨Leo queen 👑 Southern made shawty. I’m lit, you gon love it here 💅🏽
# Location:Houston, TX
# Following Count:1156
# Follower Count:1462
# Total Tweets:5439
# Retweet Count:0
# Tweet Text:@ITM_Ju3 See no I don’t like you. You will not disrespect Batman 😒
# Hashtags Used:[]
#
# Tweet 70:
# Username:GamerShanePlays
# Description:Raised $1100/$1200 in '19/'20 for Autism Canada
#
# Enjoy photography (irl and games) Autism awareness supporter,  son is non verbal
#
# He/Him
#
# Beardy_709 on IG
# Location:Canada
# Following Count:227
# Follower Count:137
# Total Tweets:8051
# Retweet Count:0
# Tweet Text:@OfficBloodKlotz @Narly9999 @JoshuaPotash Clearly you havent seen batman in the 70s https://t.co/mj93N2cFHg
# Hashtags Used:[]
#
# Tweet 71:
# Username:fantasyflying
# Description:Fantasy Art: The Gifts: Sci-fi, Horror, Art, Fashion, Jewelry, Fantasy Gifts, Toys, Electronics, Book and Music Resources https://t.co/WsTvkX6Lke
# Location:
# Following Count:586
# Follower Count:415
# Total Tweets:27234
# Retweet Count:0
# Tweet Text:"Ad:" 1990 The Dark Knight Collection Tec-Shield Batman Category: TV, Movie &amp; Video Games Location: North Richland Hills, TX, USA... - https://t.co/rFxcpd3ZHl https://t.co/7cBYmxrZDJ
# Hashtags Used:[]
#
# Tweet 72:
# Username:cosqF
# Description:Cosq | the future is meaningless the pasta is now | I draw look here: @ImCosq | bandori! | | INTP-A | @yukinnies is very pog✨
# Location:she/her | 🇵🇹
# Following Count:490
# Follower Count:292
# Total Tweets:27760
# Retweet Count:0
# Tweet Text:and I wont bother charming my clothes, oversized white sweater with my awesome batman pajama pants it will be
# Hashtags Used:[]
#
# Tweet 73:
# Username:funk3ymunk3y
# Description:
# Location:Location: Purgatory
# Following Count:147
# Follower Count:67
# Total Tweets:1323
# Retweet Count:0
# Tweet Text:@LosLeeds At least you got a free Batman mask
# Hashtags Used:[]
#
# Tweet 74:
# Username:valuntyn
# Description:17 | #bassboys
# Location:⟔ they/them | bi ⟓
# Following Count:321
# Follower Count:293
# Total Tweets:545
# Retweet Count:0
# Tweet Text:@bwuises lior house grabbin the @s for the twitter mootz 😁🤷‍♂️ feel like batman rn
# Hashtags Used:[]
#
# Tweet 75:
# Username:ExtremeV1
# Description:Matt Hardy's top guy!
# Hardy boyz fan, Artist, Gamer & a Superhero 🦇
# Location:Gotham City
# Following Count:863
# Follower Count:1613
# Total Tweets:97726
# Retweet Count:4
# Tweet Text:Hot Toys has announced new Batman Forever figures of Batman in his Sonar Suit and Robin.
#
# https://t.co/TPs4I3LxUs
# Hashtags Used:[]
#
# Tweet 76:
# Username:sburnett729
# Description:
# Location:
# Following Count:541
# Follower Count:108
# Total Tweets:11084
# Retweet Count:0
# Tweet Text:@wondermeg_ its also not like Batman is going to be full frontal(but a boy can dream)...its going to be the same CBM violence with maybe more blood than normal
# Hashtags Used:[]
#
# Tweet 77:
# Username:FuckleMcKnuckle
# Description:........pretty certain a fox recognised me once.........................that's about it... *gallops off into the distance astride a unicorn*
# Location:Liverpool, England
# Following Count:437
# Follower Count:275
# Total Tweets:11117
# Retweet Count:0
# Tweet Text:New tee skillz! 👬🏻🏳️‍🌈 #Batman #Superman #DC
#
# Lois: What does the 'S' stand for??
#
# Clark: 'Sexy Goddamn Batman' that's what it stands for!! https://t.co/3B78NJtiOg
# Hashtags Used:['Batman', 'Superman', 'DC']
#
# Tweet 78:
# Username:Stuntman_MIK3
# Description:#ZackSnydersJusticeLeague #RestoreTheSnyderverse #Film #Geek #Travel #Fitness #Gaming ASSOCIATE PRODUCER FOR ZACK SNYDERS JUSTICE LEAGUE #Foodie Twitch Streamer
# Location:Babylon 5
# Following Count:2255
# Follower Count:1293
# Total Tweets:15572
# Retweet Count:4
# Tweet Text:Haters: JUSTICE LEAGUE SHOULDNT BE R.COMIC BOOK MOVIES ARE FOR KIDS.
#
# Me: Why weren't you this angry over Logan or Deadpool 1/2
#
# Haters: (Argument changes) Well...Those guys had mature comics.
#
# Me: So has Batman/The Flash/Superman etc
#
# Haters: *stuttering* uhh Fuck Zack Snyder https://t.co/CQC2oET9p6
# Hashtags Used:[]
#
# Tweet 79:
# Username:4KUYO
# Description:Where in the world are you? | #ThankYouSorachi
# Location:
# Following Count:694
# Follower Count:985
# Total Tweets:26516
# Retweet Count:0
# Tweet Text:@Nullalb watch batman under the red hood
# Hashtags Used:[]
#
# Tweet 80:
# Username:darcbossLFS
# Description:#AFC #Milnerite #NTBK #LFS
# Location:Trinidad and Tobago
# Following Count:460
# Follower Count:280
# Total Tweets:21534
# Retweet Count:2
# Tweet Text:Batman? Fighting? Robin? https://t.co/HiulRBCAzk https://t.co/1keoLYEK5V
# Hashtags Used:[]
#
# Tweet 81:
# Username:DanielRGerard
# Description:EMS expert extraordinaire, nurse, paramedic, Newark boy (born and bred). President-Elect International Association of EMS Chiefs
# Location:San Francisco, CA
# Following Count:885
# Follower Count:1125
# Total Tweets:12739
# Retweet Count:0
# Tweet Text:@theHappyMedic I have my Batman costume on now...
# Hashtags Used:[]
#
# Tweet 82:
# Username:derealAlien
# Description:Interplanetary Junkyard Sculptor Cordutzar. Exhibiting my lovely alien junk. On a quest to explore Uranus.  Sporting six prehensile nipples + a big blow hole.
# Location:Mare Humorum
# Following Count:5003
# Follower Count:2345
# Total Tweets:115361
# Retweet Count:6
# Tweet Text:Monk is a better detective than Batman.
# Hashtags Used:[]
#
# Tweet 83:
# Username:surroundgatari
# Description:Smile please
# Location:22 shots to my grill
# Following Count:274
# Follower Count:211
# Total Tweets:6122
# Retweet Count:0
# Tweet Text:@FASTDIV3 lil niggas are robins we all Batman
# Hashtags Used:[]
#
# Tweet 84:
# Username:Silent_Riot5225
# Description:Certified Salesforce Admin ☁️ Software Developer 💻 #ImBlackInTech #BlackTechTwitter #YGB #WakandaForever 🙅🏾‍♀️ Views my own (She/Her)
# Location:North Carolina, USA
# Following Count:716
# Follower Count:523
# Total Tweets:5368
# Retweet Count:0
# Tweet Text:@fredrickl I’m going to take the cartoon approach 🙃🙃
#
# Wade from Kim Possible
# Max Gibson from Batman Beyond
# Hashtags Used:[]
#
# Tweet 85:
# Username:GingerHotDish
# Description:@momonfire is no sidekick. #FuckCancer
# Location:Forever and a day, 17+33
# Following Count:7362
# Follower Count:52783
# Total Tweets:297913
# Retweet Count:6
# Tweet Text:Monk is a better detective than Batman.
# Hashtags Used:[]
#
# Tweet 86:
# Username:willGDavis
# Description:DC fans are eating pretty good rn #GothamKights #SuicideSquadGame #SupermanGang #ManOfSteel2
# Location:Greensboro, NC
# Following Count:463
# Follower Count:271
# Total Tweets:8339
# Retweet Count:2
# Tweet Text:The cinematography of The Batman is amazing. the perspectives, the natural colors it has, the camera angles etc. no doubt greg fraser will win an award for his great work !! https://t.co/rAoeVEZB8C
# Hashtags Used:[]
#
# Tweet 87:
# Username:AnaNoMus98
# Description:BK | Wellesley 20 | 💕💚
# Location:
# Following Count:86
# Follower Count:82
# Total Tweets:620
# Retweet Count:3
# Tweet Text:Batman fighting robin pull up!!
# Hashtags Used:[]
#
# Tweet 88:
# Username:toaster_ass
# Description:Streamer || 16 || She/Her || Spotify Account: @spotify_the
# Location:
# Following Count:285
# Follower Count:19
# Total Tweets:708
# Retweet Count:61
# Tweet Text:"tommy, you wanna be a hero, right? you wanna be the hero of the server and every hero needs an origin story, right? i mean batman had his parents, spider-man had uncle ben... you have tubbo.”
# Hashtags Used:[]
#
# Tweet 89:
# Username:snactasha
# Description:jennifer check & cassandra thomas text me. them/they/her. 21. ask me about proctoring your test, today.
# Location:on a journey to the past
# Following Count:224
# Follower Count:41
# Total Tweets:14447
# Retweet Count:78
# Tweet Text:and that was the first night bella dreamt of batman https://t.co/4Ug646UBMc
# Hashtags Used:[]
#
# Tweet 90:
# Username:SplrisFlwerCrwn
# Description:seriously GO WATCH #GLITCHTECHS it's a good show that deserves more seasons!
# Location:
# Following Count:1891
# Follower Count:281
# Total Tweets:88181
# Retweet Count:3
# Tweet Text:oh look another batman story... haven't heard of that before https://t.co/pojfruhFuu https://t.co/zhPBzAr39X
# Hashtags Used:[]
#
# Tweet 91:
# Username:JmelykBee
# Description:←cinema→
# Location:Україна
# Following Count:706
# Follower Count:108
# Total Tweets:6900
# Retweet Count:2
# Tweet Text:The cinematography of The Batman is amazing. the perspectives, the natural colors it has, the camera angles etc. no doubt greg fraser will win an award for his great work !! https://t.co/rAoeVEZB8C
# Hashtags Used:[]
#
# Tweet 92:
# Username:hardnaqlife
# Description:here but im gone
# Location:queens • boston
# Following Count:302
# Follower Count:618
# Total Tweets:5430
# Retweet Count:56444
# Tweet Text:Joker learned Batman’s identity and immediately started asking the real questions. My goat https://t.co/9UekBwUrV3
# Hashtags Used:[]
#
# Tweet 93:
# Username:HLSEntrtainment
# Description:HLS Entertainment, movie/tv reviews and theories as well sports coverage we have it all! Main account @HaroldLStokes
# Location:
# Following Count:74
# Follower Count:5
# Total Tweets:434
# Retweet Count:1
# Tweet Text:I’m getting close to finishing Part 2 so I figured I should pump this back out there! I’d love to hear all of your thoughts!
#
# #ZackSnydersJusticeLeague #rayfisher #WonderWoman1984  #Batman
#
# The StokesVerse: If I was put in charge of the DCEU back in 2012 https://t.co/PBLVm7cNyq https://t.co/BFl3PnPGjO
# Hashtags Used:[]
# Tweet 94:
# Username:Batman_Beware
# Description:Yes this is that Batman guy who people accidentally follow, don't be one of those people... Beware the Batman!
# Location:Gotham City
# Following Count:780
# Follower Count:3017
# Total Tweets:116291
# Retweet Count:230
# Tweet Text:It’s official: Jackie Robinson graces on the cover of MLB The Show 21’s Collector’s Editions.
#
# Full details: https://t.co/SKS2RqTMNa https://t.co/jSFcdrpPg1
# Hashtags Used:[]
#
# Tweet 95:
# Username:Z5cathy
# Description:a fan account
# Location:usa
# Following Count:3439
# Follower Count:2319
# Total Tweets:296950
# Retweet Count:6
# Tweet Text:I’m glad Robert Pattinson’s Batman is acknowledging the eye makeup that goes with cowls and domino masks in DC. I always wondered how they could pull off that thing where it just magically disappears once the mask/cowl is removed. https://t.co/fze0dLr15c
# Hashtags Used:[]
#
# Tweet 96:
# Username:Ioveneone
# Description:ᴅᴀʏꜱ: ᴘᴇᴀᴄᴇꜰᴜʟ | ɴɪɢʜᴛꜱ: ᴄᴏʟᴏᴜʀꜰᴜʟ | ᴅʀᴇᴀᴍꜱ: ꜰʀᴜɪᴛꜰᴜʟ
# Location:she/her
# Following Count:666
# Follower Count:829
# Total Tweets:20724
# Retweet Count:99
# Tweet Text:Love this Batman moment so much https://t.co/Gr6Tx99emK
# Hashtags Used:[]
#
# Tweet 97:
# Username:carlossolorza12
# Description:DREAM CHASER- ITESM GDL LED ⚖️
# Location:Guadalajara, Jalisco
# Following Count:368
# Follower Count:340
# Total Tweets:5755
# Retweet Count:2090
# Tweet Text:Tom Holland says that while filming 'Spider-Man: Homecoming' (2017), Michael Keaton would whisper 'I'm Batman' during fight scenes https://t.co/7MQDwfBpTq
# Hashtags Used:[]
#
# Tweet 98:
# Username:Chadmw10
# Description:Movie fan, Sports fan, part geek
# Location:Greater Sudbury / Grand Sudbury, Ontario
# Following Count:107
# Follower Count:18
# Total Tweets:3012
# Retweet Count:0
# Tweet Text:@MikeKalinowski @WilliamBibbiani I think the difference though is deadpool as always been somewhat of a rated R character , even in the comics, but people expect a movie with Superman, Wonder Woman and Batman to be accessible to all viewers.  I may not agree, but I can understand that view.
# Hashtags Used:[]
#
# Tweet 99:
# Username:Edwin_A_Santos
# Description:#Actor | Founder, Filipino Hollywood @ActorsPanel | #Producer, "Mad Cowgirl" on @PrimeVideo and @Tubi | Listed in 75 Most Influential Filipino-Americans of 2020
# Location:Los Angeles, California
# Following Count:828
# Follower Count:1085
# Total Tweets:22167
# Retweet Count:0
# Tweet Text:I'm Fil-Am Batman!
#
# https://t.co/OK8gGCFYQA
# Hashtags Used:[]
#
# Tweet 100:
# Username:esoridnas
# Description:it's sandi with an i
# Location:she/her
# Following Count:101
# Follower Count:71
# Total Tweets:2099
# Retweet Count:0
# Tweet Text:This taco place I've been wanting to try launched a taco last year that was tributed to Chicano Batman and THEYRE TAKING OT OFF THE MENU THIS WEEK AND I NEVER GOT TO TRY IT!!!! I have to go have the Chicano Batman taco this week guys!!!!
# Hashtags Used:[]
# Scraping has completed!
